# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Robust_SlotFilling
# Out:
# /content/drive/MyDrive/Robust_SlotFilling

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.27.3-py3-none-any.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 52.2 MB/s eta 0:00:00
# Requirement already satisfied: ipython in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 2)) (7.9.0)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 3)) (5.3.4)
# Requirement already satisfied: notebook in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 4)) (6.3.0)
# Collecting jupyter
#   Downloading jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 6)) (1.13.1+cu116)
# Collecting loguru
#   Downloading loguru-0.6.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 KB 8.1 MB/s eta 0:00:00
# Collecting datasets
#   Downloading datasets-2.10.1-py3-none-any.whl (469 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 KB 39.9 MB/s eta 0:00:00
# Collecting wandb
#   Downloading wandb-0.14.0-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 55.0 MB/s eta 0:00:00
# Collecting evaluate
#   Downloading evaluate-0.4.0-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 KB 10.2 MB/s eta 0:00:00
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 KB 5.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 97.9 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers->-r requirements.txt (line 1)) (2.27.1)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.13.3-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.8/199.8 KB 21.7 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers->-r requirements.txt (line 1)) (4.65.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers->-r requirements.txt (line 1)) (2022.10.31)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers->-r requirements.txt (line 1)) (1.22.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers->-r requirements.txt (line 1)) (3.10.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers->-r requirements.txt (line 1)) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers->-r requirements.txt (line 1)) (6.0)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 76.9 MB/s eta 0:00:00
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.9/dist-packages (from ipython->-r requirements.txt (line 2)) (67.6.0)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.9/dist-packages (from ipython->-r requirements.txt (line 2)) (5.7.1)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.9/dist-packages (from ipython->-r requirements.txt (line 2)) (4.8.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from ipython->-r requirements.txt (line 2)) (2.0.10)
# Requirement already satisfied: backcall in /usr/local/lib/python3.9/dist-packages (from ipython->-r requirements.txt (line 2)) (0.2.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.9/dist-packages (from ipython->-r requirements.txt (line 2)) (2.14.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.9/dist-packages (from ipython->-r requirements.txt (line 2)) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.9/dist-packages (from ipython->-r requirements.txt (line 2)) (0.7.5)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.9/dist-packages (from ipykernel->-r requirements.txt (line 3)) (6.2)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.9/dist-packages (from ipykernel->-r requirements.txt (line 3)) (6.1.12)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.9/dist-packages (from notebook->-r requirements.txt (line 4)) (0.2.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in /usr/local/lib/python3.9/dist-packages (from notebook->-r requirements.txt (line 4)) (1.8.0)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.9/dist-packages (from notebook->-r requirements.txt (line 4)) (21.3.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from notebook->-r requirements.txt (line 4)) (3.1.2)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.9/dist-packages (from notebook->-r requirements.txt (line 4)) (23.2.1)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.9/dist-packages (from notebook->-r requirements.txt (line 4)) (5.3.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.9/dist-packages (from notebook->-r requirements.txt (line 4)) (5.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.9/dist-packages (from notebook->-r requirements.txt (line 4)) (0.17.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.9/dist-packages (from notebook->-r requirements.txt (line 4)) (0.16.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.9/dist-packages (from notebook->-r requirements.txt (line 4)) (6.5.4)
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.9/dist-packages (from jupyter->-r requirements.txt (line 5)) (6.1.0)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.9/dist-packages (from jupyter->-r requirements.txt (line 5)) (7.7.1)
# Collecting qtconsole
#   Downloading qtconsole-5.4.1-py3-none-any.whl (120 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.9/120.9 KB 16.0 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch->-r requirements.txt (line 6)) (4.5.0)
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 KB 24.2 MB/s eta 0:00:00
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py39-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 KB 17.2 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.9/dist-packages (from datasets->-r requirements.txt (line 8)) (2023.3.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from datasets->-r requirements.txt (line 8)) (1.4.4)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.9/dist-packages (from datasets->-r requirements.txt (line 8)) (9.0.0)
# Collecting dill<0.3.7,>=0.3.0
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 KB 14.8 MB/s eta 0:00:00
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 66.3 MB/s eta 0:00:00
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.9/dist-packages (from wandb->-r requirements.txt (line 9)) (5.9.4)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.18.0-py2.py3-none-any.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 KB 23.2 MB/s eta 0:00:00
# Collecting GitPython!=3.1.29,>=1.0.0
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 24.5 MB/s eta 0:00:00
# Collecting setproctitle
#   Downloading setproctitle-1.3.2-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.9/dist-packages (from wandb->-r requirements.txt (line 9)) (1.4.4)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.15.0 in /usr/local/lib/python3.9/dist-packages (from wandb->-r requirements.txt (line 9)) (3.19.6)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.9/dist-packages (from wandb->-r requirements.txt (line 9)) (8.1.3)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.9/dist-packages (from seqeval->-r requirements.txt (line 11)) (1.2.2)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.9/dist-packages (from docker-pycreds>=0.4.0->wandb->-r requirements.txt (line 9)) (1.16.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets->-r requirements.txt (line 8)) (2.0.12)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 14.2 MB/s eta 0:00:00
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (264 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 31.4 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 19.4 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets->-r requirements.txt (line 8)) (22.2.0)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 7.2 MB/s eta 0:00:00
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.9/dist-packages (from jedi>=0.10->ipython->-r requirements.txt (line 2)) (0.8.3)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.9/dist-packages (from jupyter-client->ipykernel->-r requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.9/dist-packages (from jupyter-core>=4.6.1->notebook->-r requirements.txt (line 4)) (3.1.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.9/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->-r requirements.txt (line 2)) (0.2.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers->-r requirements.txt (line 1)) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers->-r requirements.txt (line 1)) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers->-r requirements.txt (line 1)) (1.26.15)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.21.3->seqeval->-r requirements.txt (line 11)) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.21.3->seqeval->-r requirements.txt (line 11)) (1.1.1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.21.3->seqeval->-r requirements.txt (line 11)) (1.10.1)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.9/dist-packages (from terminado>=0.8.3->notebook->-r requirements.txt (line 4)) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.9/dist-packages (from argon2-cffi->notebook->-r requirements.txt (line 4)) (21.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->jupyter->-r requirements.txt (line 5)) (3.6.3)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->jupyter->-r requirements.txt (line 5)) (3.0.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->notebook->-r requirements.txt (line 4)) (2.1.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook->-r requirements.txt (line 4)) (4.9.2)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook->-r requirements.txt (line 4)) (0.2.2)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook->-r requirements.txt (line 4)) (0.7.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook->-r requirements.txt (line 4)) (6.0.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook->-r requirements.txt (line 4)) (1.2.1)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook->-r requirements.txt (line 4)) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook->-r requirements.txt (line 4)) (1.5.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook->-r requirements.txt (line 4)) (4.11.2)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook->-r requirements.txt (line 4)) (0.4)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook->-r requirements.txt (line 4)) (0.8.4)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.9/dist-packages (from nbformat->notebook->-r requirements.txt (line 4)) (4.3.3)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.9/dist-packages (from nbformat->notebook->-r requirements.txt (line 4)) (2.16.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->datasets->-r requirements.txt (line 8)) (2022.7.1)
# Collecting qtpy>=2.0.1
#   Downloading QtPy-2.3.0-py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.6/83.6 KB 11.2 MB/s eta 0:00:00
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=2.6->nbformat->notebook->-r requirements.txt (line 4)) (0.19.3)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook->-r requirements.txt (line 4)) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4->nbconvert->notebook->-r requirements.txt (line 4)) (2.4)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.9/dist-packages (from bleach->nbconvert->notebook->-r requirements.txt (line 4)) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->-r requirements.txt (line 4)) (2.21)
# Building wheels for collected packages: seqeval, pathtools
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16180 sha256=2a1f25a4ad8db293a2d9b9832a006abb50087a4773a2cecc982ae708a157cc12
#   Stored in directory: /root/.cache/pip/wheels/e2/a5/92/2c80d1928733611c2747a9820e1324a6835524d9411510c142
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8807 sha256=ea261d4c59591ede19368855ec74d38c9c995f0616101c6cca05f563a4531839
#   Stored in directory: /root/.cache/pip/wheels/b7/0a/67/ada2a22079218c75a88361c0782855cc72aebc4d18d0289d05
# Successfully built seqeval pathtools
# Installing collected packages: tokenizers, pathtools, xxhash, smmap, setproctitle, sentry-sdk, qtpy, multidict, loguru, jedi, frozenlist, docker-pycreds, dill, async-timeout, yarl, responses, multiprocess, huggingface-hub, gitdb, aiosignal, transformers, seqeval, GitPython, aiohttp, wandb, qtconsole, datasets, evaluate, jupyter
# Successfully installed GitPython-3.1.31 aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 datasets-2.10.1 dill-0.3.6 docker-pycreds-0.4.0 evaluate-0.4.0 frozenlist-1.3.3 gitdb-4.0.10 huggingface-hub-0.13.3 jedi-0.18.2 jupyter-1.0.0 loguru-0.6.0 multidict-6.0.4 multiprocess-0.70.14 pathtools-0.1.2 qtconsole-5.4.1 qtpy-2.3.0 responses-0.18.0 sentry-sdk-1.18.0 seqeval-1.2.2 setproctitle-1.3.2 smmap-5.0.0 tokenizers-0.13.2 transformers-4.27.3 wandb-0.14.0 xxhash-3.2.0 yarl-1.8.2

# %%
# !wandb login
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
import json
import pandas as pd
import transformers
from typing import List
import re
import matplotlib.pyplot as plt
import numpy as np
import wandb

# %% [markdown]
# # Data Pre-processing

# %%
train_data = pd.read_json('./data/train_Mar-22-2023.json')
val_data = pd.read_json('./data/val_Mar-22-2023.json')

# %%
combined_data = [train_data, val_data]

# %%
data = pd.concat(combined_data, ignore_index=True)

# %%
def label_with_bio(full_text, spans, template_id):
    """
    Takes full-text utterances and spans (containing entity value and entity type) and creates B-I-O labels

    Args:
        df (pd.DataFrame): DataFrame with utterances, annotations, metadata, and ner-tags.
    Returns:
        id2labels (dict): dictionary with integer ids as keys and associated tags (one per id) as values
        dict (dict): dictionary with tags as keys and associated integer ids (one per tag) as values
        
    """
    words = full_text.split()
    ner_tags = ['O']*len(words)

    SPECIAL_CHAR_REGEX = re.compile(r"(\w+)([\.\?\!\,\:\'])\B")
    
    words = [re.sub(SPECIAL_CHAR_REGEX, r"\g<1>", word) for word in words]
    
    try:

        for span in spans:

        # # Handle rogue IP Address case
        #     if(template_id == 37):
        #         ner_tags[-1] = 'B-' + span['entity_type']
        #         ner_tags[-1] = span['entity_type']
        #         return ner_tags


            entity_words = span['entity_value'].split()
            entity_words = [re.sub(SPECIAL_CHAR_REGEX, r"\g<1>", word) for word in entity_words]

            span_labels = ['I-' + span['entity_type']]*len(entity_words)
            span_labels[0] = 'B-' + span['entity_type']
            # span_labels[-1] = 'E-' + span['entity_type']

                
            start_idx = words.index(entity_words[0])
            end_idx = words.index(entity_words[-1])

        
            if start_idx - end_idx != 0:
                ner_tags[start_idx:end_idx + 1] = span_labels
            else:
                ner_tags[start_idx] = span_labels[0]
        
        return ner_tags
    
    
    except:
        return "Null"

# %% [markdown]
# # Sample Data

# %%
full_text = "When they weren't singing about Hobbits, satanic felines and interstellar journeys, they were singing about the verses from Carla Pinto's Cautionary Tales. Is there a better example of unbridled creativity than early Pinto?"

spans = [
            {
                "entity_type": "PERSON",
                "entity_value": "Pinto",
                "start_position": 217,
                "end_position": 222
            },
            {
                "entity_type": "PERSON",
                "entity_value": "Carla Pinto",
                "start_position": 124,
                "end_position": 135
            }
        ]

# %%
ner_tags = label_with_bio(full_text, spans, 10)

# %% [markdown]
# # Data Labeling

# %%
def get_label_ids(df: pd.DataFrame)-> (dict, dict):
    """
    Takes a DataFrame with token labels (O, B-provider, I-specialty) and creates mappings
    from unique integer ids to tokens and vice versa.

    Args:
        df (pd.DataFrame): DataFrame with utterances, annotations, metadata, and ner-tags.
    Returns:
        id2labels (dict): dictionary with integer ids as keys and associated tags (one per id) as values
        dict (dict): dictionary with tags as keys and associated integer ids (one per tag) as values
    """
    unique_tags = list(set([item for sublist in list(df["ner_tags_text"]) for item in sublist]))
    id2label, label2id = {}, {}
    for ind, tag in enumerate(unique_tags):
        id2label[ind], label2id[tag]= tag, ind
    return id2label, label2id

# %%
def convert_label_to_id(labels: List[str], label2id) -> List[int]:
    """
    Converts a list of labels (O, O, B-specialty) to a list of ids (0, 0, 5)

    Args:
        labels (List[str]): list of token labels in text
        label2id (dict): dictionary mapping labels to unique ids

    Returns:
        List[int]: mapping of input text token labels to integer token labels
    """
    return[label2id[label] for label in labels]

# %%
def populate_df_with_labels(data, id2label, label2id):

    data['ner_tags_text'] = data.apply(lambda x: label_with_bio(x.full_text, x.spans, x.template_id), axis=1)

    # Remove labels 
    data = data[data['ner_tags_text'] != "Null"]
    data["tokens"] = data['full_text'].apply(lambda x: x.split())
     

    data["ner_tags"] = data["ner_tags_text"].apply(lambda x: convert_label_to_id(x, label2id))

    # Removing invalid labels
    data['token_length'] = data.tokens.apply(lambda x: len(x))
    data['tag_length'] = data.ner_tags.apply(lambda x: len(x))
    data["difference"] = data.token_length - data.tag_length
    data = data[data['difference'] == 0]

    return data

# %%
data['ner_tags_text'] = data.apply(lambda x: label_with_bio(x.full_text, x.spans, x.template_id), axis=1)
data = data[data['ner_tags_text'] != "Null"]
data["tokens"] = data['full_text'].apply(lambda x: x.split())

id2label, label2id = get_label_ids(data)

data["ner_tags"] = data["ner_tags_text"].apply(lambda x: convert_label_to_id(x, label2id))
data['token_length'] = data.tokens.apply(lambda x: len(x))
data['tag_length'] = data.ner_tags.apply(lambda x: len(x))
data["difference"] = data.token_length - data.tag_length
data = data[data['difference'] == 0]
# Out:
# <ipython-input-16-fe1605edf66e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["tokens"] = data['full_text'].apply(lambda x: x.split())
# <ipython-input-16-fe1605edf66e>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["ner_tags"] = data["ner_tags_text"].apply(lambda x: convert_label_to_id(x, label2id))
# <ipython-input-16-fe1605edf66e>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['token_length'] = data.tokens.apply(lambda x: len(x))
# <ipython-input-16-fe1605edf66e>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['tag_length'] = data.ner_tags.apply(lambda x: len(x))
# <ipython-input-16-fe1605edf66e>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["difference"] = data.token_length - data.tag_length

# %% [markdown]
# ## Populate dataframe with BIO labels

# %%
train_data = populate_df_with_labels(train_data, id2label, label2id)

# %%
val_data = populate_df_with_labels(val_data, id2label, label2id)

# %%
len(train_data)
# Out:
# 149

# %%
len(val_data)
# Out:
# 44

# %% [markdown]
# # Model Training

# %%
from datasets import Dataset, Features, Value, ClassLabel, Sequence
from transformers import AutoTokenizer, AutoModel

# %%
class TCDataMaker:
    def __init__(self, df: pd.DataFrame, id2label: dict,  label2id: dict):
        self.id2label = id2label
        self.label2id = label2id
        self.ner_tags = []
        self.tokens = []
        self.ids = []
        
        for ind, row in df.iterrows():
            self.ner_tags.append(row["ner_tags"])
            self.tokens.append(row["tokens"])
            self.ids.append(ind)
            
        self.data = {
            "id": self.ids,
            "ner_tags": self.ner_tags,
            "tokens": self.tokens
        }  
    
    def get_dataset(self):
        features = Features({
            "tokens": Sequence(Value("string")),
            "ner_tags": Sequence(ClassLabel(names=list(id2label.values()))),
            "id": Value("int32")
        })
        return Dataset.from_dict(self.data, features)

# %%
train_datamaker = TCDataMaker(train_data,id2label,label2id)
val_datamaker = TCDataMaker(val_data,id2label,label2id)

# %%
train_ner_dataset = train_datamaker.get_dataset()
val_ner_dataset = val_datamaker.get_dataset()

# %%
from datasets import Dataset
from transformers import AutoTokenizer,DataCollatorForTokenClassification

# %%
tokenizer = AutoTokenizer.from_pretrained("StanfordAIMI/stanford-deidentifier-base")

# %%
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.19k [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
data_collator = DataCollatorForTokenClassification(tokenizer=tokenizer)

# %%
def tokenize_and_align_labels(examples):
    tokenized_inputs = tokenizer(examples["tokens"], truncation=True, is_split_into_words=True)

    labels = []
    for i, label in enumerate(examples["ner_tags"]):
        word_ids = tokenized_inputs.word_ids(batch_index=i)  # Map tokens to their respective word.
        previous_word_idx = None
        label_ids = []
        for word_idx in word_ids:  # Set the special tokens to -100.
            # print(word_idx)
            if word_idx is None:
                label_ids.append(-100)
            elif word_idx != previous_word_idx:  # Only label the first token of a given word.
                label_ids.append(label[word_idx])
            else:
                label_ids.append(-100)
            previous_word_idx = word_idx
        labels.append(label_ids)

    tokenized_inputs["labels"] = labels
    return tokenized_inputs

# %%
tokenized_train_dataset = train_ner_dataset.map(tokenize_and_align_labels, batched=True)
tokenized_val_dataset = val_ner_dataset.map(tokenize_and_align_labels, batched=True)
# Out:
# Map:   0%|          | 0/149 [00:00<?, ? examples/s]
# Map:   0%|          | 0/44 [00:00<?, ? examples/s]

# %%
label_list = list(label2id.keys())

# %%
import evaluate
import random
def compute_metrics(eval_preds):
  metric = evaluate.load("f1")

  results = {}

  predictions, labels = eval_preds
  predictions = np.argmax(predictions, axis=2)

  true_predictions = [
      [label_list[p] for (p, l) in zip(prediction, label) if l != -100]
      for prediction, label in zip(predictions, labels)
  ]
  true_labels = [
      [label_list[l] for (p, l) in zip(prediction, label) if l != -100]
      for prediction, label in zip(predictions, labels)
  ]

  true_predictions = [p for pred in true_predictions for p in pred]
  true_labels = [l for label in true_labels for l in label]
  

  true_predictions = [label2id[pred] for pred in true_predictions]
  true_labels = [label2id[label] for label in true_labels]

  for label in set(true_labels):
    binary_predictions = [1 if pred == label else 0 for pred in true_predictions]
    binary_labels = [1 if l == label else 0 for l in true_labels]
    results[id2label[label]] = metric.compute(predictions=binary_predictions, references=binary_labels, average="binary")["f1"]

  return(results)

# %%
from transformers import AutoModelForTokenClassification, TrainingArguments, Trainer
from transformers import BertForTokenClassification


model = BertForTokenClassification.from_pretrained("StanfordAIMI/stanford-deidentifier-base", num_labels=len(id2label), id2label=id2label, label2id=label2id, ignore_mismatched_sizes=True)

training_args = TrainingArguments(
    output_dir="./results/de_identification",
    overwrite_output_dir=True,
    logging_strategy='steps',
    logging_steps=1,
    logging_dir='/content/drive/MyDrive/Robust_SlotFilling/results/runs',
    report_to="wandb",
    run_name="manual-dataset-run-3-195-stanford",
    warmup_steps=0,
    evaluation_strategy="steps",
    eval_steps=1,
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=20,
    weight_decay=0.01,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_train_dataset,
    eval_dataset=tokenized_val_dataset,
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics
)

trainer.train()

# %%
from transformers import pipeline

# %% [markdown]
# ## Loading Model

# %%
tokenizer = AutoTokenizer.from_pretrained("./results/de_identification/checkpoint-500/")
model = AutoModelForTokenClassification.from_pretrained("./results/de_identification/checkpoint-500/")

# %% [markdown]
# # Model Testing

# %%
token_classifier = pipeline("token-classification", model=model, tokenizer=tokenizer, aggregation_strategy= "average", device='cuda:0')

# %%
token_classifier(val_data.full_text.to_list())
# Out:
# [[{'entity_group': 'ORGANIZATION',
#    'score': 0.73633033,
#    'word': 'kragen auto parts',
#    'start': 0,
#    'end': 17}],
#  [{'entity_group': 'GPE',
#    'score': 0.9432222,
#    'word': 'germany',
#    'start': 18,
#    'end': 25}],
#  [{'entity_group': 'EMAIL_ADDRESS',
#    'score': 0.9346185,
#    'word': 'aleahdocherty',
#    'start': 23,
#    'end': 36},
#   {'entity_group': 'EMAIL_ADDRESS',
#    'score': 0.8133048,
#    'word': '@',
#    'start': 36,
#    'end': 37},
#   {'entity_group': 'ORGANIZATION',
#    'score': 0.48778424,
#    'word': 'jourrapide',
#    'start': 37,
#    'end': 47},
#   {'entity_group': 'ORGANIZATION',
#    'score': 0.31336486,
#    'word': '. com',
#    'start': 47,
#    'end': 51}],
#  [{'entity_group': 'TITLE',
#    'score': 0.94536376,
#    'word': 'mrs',
#    'start': 84,
#    'end': 87},
#   {'entity_group': 'TITLE',
#    'score': 0.5880402,
#    'word': '.',
#    'start': 87,
#    'end': 88},
#   {'entity_group': 'PERSON',
#    'score': 0.93396324,
#    'word': 'thea solberg',
#    'start': 89,
#    'end': 101}],
#  [{'entity_group': 'PERSON',
#    'score': 0.8873703,
#    'word': 'emily',
#    'start': 30,
#    'end': 35}],
#  [{'entity_group': 'STREET_ADDRESS',
#    'score': 0.9726912,
#    'word': '7497 holmevej 34 suite 117 apt. 006, kangilinnguit, greenlander 80919, and 394 heirstraat 58 apt. 335 malonne belgium',
#    'start': 43,
#    'end': 160}],
#  [{'entity_group': 'ORGANIZATION',
#    'score': 0.76262486,
#    'word': 'abc markets',
#    'start': 0,
#    'end': 11},
#   {'entity_group': 'ORGANIZATION',
#    'score': 0.43553337,
#    'word': 'investment bank and financial services',
#    'start': 31,
#    'end': 69}],
#  [{'entity_group': 'CREDIT_CARD',
#    'score': 0.9663597,
#    'word': '4382621551378139',
#    'start': 55,
#    'end': 71},
#   {'entity_group': 'EMAIL_ADDRESS',
#    'score': 0.89475805,
#    'word': 'dyanvangijn',
#    'start': 85,
#    'end': 96},
#   {'entity_group': 'EMAIL_ADDRESS',
#    'score': 0.5208229,
#    'word': '@',
#    'start': 96,
#    'end': 97},
#   {'entity_group': 'ORGANIZATION',
#    'score': 0.40023994,
#    'word': 'dayrep',
#    'start': 97,
#    'end': 103}],
#  [{'entity_group': 'ORGANIZATION',
#    'score': 0.73104525,
#    'word': 'maxi',
#    'start': 4,
#    'end': 8},
#   {'entity_group': 'ORGANIZATION',
#    'score': 0.62294924,
#    'word': '- tech',
#    'start': 8,
#    'end': 13},
#   {'entity_group': 'DATE_TIME',
#    'score': 0.88755393,
#    'word': '1947',
#    'start': 39,
#    'end': 43},
#   {'entity_group': 'GPE',
#    'score': 0.83274925,
#    'word': 'southern',
#    'start': 149,
#    'end': 157},
#   {'entity_group': 'GPE',
#    'score': 0.751384,
#    'word': 'united',
#    'start': 158,
#    'end': 164},
#   {'entity_group': 'GPE',
#    'score': 0.5541894,
#    'word': 'kingdom',
#    'start': 165,
#    'end': 172}],
#  [{'entity_group': 'EMAIL_ADDRESS',
#    'score': 0.9305262,
#    'word': 'sadayonakahara',
#    'start': 57,
#    'end': 71},
#   {'entity_group': 'EMAIL_ADDRESS',
#    'score': 0.67704135,
#    'word': '@',
#    'start': 71,
#    'end': 72},
#   {'entity_group': 'EMAIL_ADDRESS',
#    'score': 0.3416828,
#    'word': 'fleckens',
#    'start': 72,
#    'end': 80},
#   {'entity_group': 'STREET_ADDRESS',
#    'score': 0.28106567,
#    'word': '. hu',
#    'start': 80,
#    'end': 83}],
#  [{'entity_group': 'STREET_ADDRESS',
#    'score': 0.98811615,
#    'word': 'usns lorenzen fpo ae 62045, and 035 74 diakou street apt. 627 suite 907, oklahoma city, united states 02247',
#    'start': 43,
#    'end': 150}],
#  [{'entity_group': 'DATE_TIME',
#    'score': 0.61198497,
#    'word': 'friday',
#    'start': 11,
#    'end': 17},
#   {'entity_group': 'STREET_ADDRESS',
#    'score': 0.87243354,
#    'word': 'tsukui staff corporation, 3346 loftaheden 37, bruzaholm',
#    'start': 21,
#    'end': 76}],
#  [{'entity_group': 'DATE_TIME',
#    'score': 0.9142951,
#    'word': '2007',
#    'start': 6,
#    'end': 10},
#   {'entity_group': 'DATE_TIME',
#    'score': 0.80077237,
#    'word': '-',
#    'start': 10,
#    'end': 11},
#   {'entity_group': 'DATE_TIME',
#    'score': 0.865521,
#    'word': '12',
#    'start': 11,
#    'end': 13},
#   {'entity_group': 'DATE_TIME',
#    'score': 0.79805374,
#    'word': '-',
#    'start': 13,
#    'end': 14},
#   {'entity_group': 'DATE_TIME',
#    'score': 0.89071566,
#    'word': '11',
#    'start': 14,
#    'end': 16},
#   {'entity_group': 'PHONE_NUMBER',
#    'score': 0.3641274,
#    'word': '12',
#    'start': 17,
#    'end': 19},
#   {'entity_group': 'DATE_TIME',
#    'score': 0.23844317,
#    'word': ':',
#    'start': 19,
#    'end': 20},
#   {'entity_group': 'PHONE_NUMBER',
#    'score': 0.27072847,
#    'word': '10 : 21',
#    'start': 20,
#    'end': 25},
#   {'entity_group': 'ORGANIZATION',
#    'score': 0.6041758,
#    'word': 'gonyu country club',
#    'start': 33,
#    'end': 51}],
#  [{'entity_group': 'TITLE',
#    'score': 0.9268098,
#    'word': 'ms',
#    'start': 23,
#    'end': 25},
#   {'entity_group': 'TITLE',
#    'score': 0.55331546,
#    'word': '.',
#    'start': 25,
#    'end': 26},
#   {'entity_group': 'PERSON',
#    'score': 0.93810725,
#    'word': 'solomina',
#    'start': 27,
#    'end': 35}],
#  [{'entity_group': 'TITLE',
#    'score': 0.90326124,
#    'word': 'mrs',
#    'start': 23,
#    'end': 26},
#   {'entity_group': 'TITLE',
#    'score': 0.52160907,
#    'word': '.',
#    'start': 26,
#    'end': 27},
#   {'entity_group': 'PERSON',
#    'score': 0.9193698,
#    'word': 'lewis',
#    'start': 28,
#    'end': 33}],
#  [{'entity_group': 'DATE_TIME',
#    'score': 0.9598687,
#    'word': 'saturday',
#    'start': 19,
#    'end': 27},
#   {'entity_group': 'PHONE_NUMBER',
#    'score': 0.9322988,
#    'word': '026 835 27 54',
#    'start': 42,
#    'end': 55}],
#  [{'entity_group': 'ORGANIZATION',
#    'score': 0.7849283,
#    'word': 'rainbow records',
#    'start': 0,
#    'end': 15},
#   {'entity_group': 'ORGANIZATION',
#    'score': 0.5020491,
#    'word': 'investment bank and financial services company',
#    'start': 35,
#    'end': 81}],
#  [{'entity_group': 'DATE_TIME',
#    'score': 0.92178684,
#    'word': '1986',
#    'start': 6,
#    'end': 10},
#   {'entity_group': 'DATE_TIME',
#    'score': 0.89076304,
#    'word': '-',
#    'start': 10,
#    'end': 11},
#   {'entity_group': 'DATE_TIME',
#    'score': 0.90408754,
#    'word': '02',
#    'start': 11,
#    'end': 13},
#   {'entity_group': 'DATE_TIME',
#    'score': 0.8890664,
#    'word': '-',
#    'start': 13,
#    'end': 14},
#   {'entity_group': 'DATE_TIME',
#    'score': 0.9157917,
#    'word': '06',
#    'start': 14,
#    'end': 16},
#   {'entity_group': 'STREET_ADDRESS',
#    'score': 0.37723988,
#    'word': '19 : 25 : 37',
#    'start': 17,
#    'end': 25},
#   {'entity_group': 'STREET_ADDRESS',
#    'score': 0.51933485,
#    'word': 'λευκωσια country club',
#    'start': 33,
#    'end': 54}],
#  [{'entity_group': 'ORGANIZATION',
#    'score': 0.43906388,
#    'word': 'jealous',
#    'start': 7,
#    'end': 14},
#   {'entity_group': 'PERSON',
#    'score': 0.7782052,
#    'word': 'hudson',
#    'start': 21,
#    'end': 27},
#   {'entity_group': 'PERSON',
#    'score': 0.92077637,
#    'word': 'katherine',
#    'start': 31,
#    'end': 40}],
#  [{'entity_group': 'STREET_ADDRESS',
#    'score': 0.97536016,
#    'word': '750 53 rue talleyrand apt. 615 sidi ahmed zarrouk tunisia',
#    'start': 43,
#    'end': 103},
#   {'entity_group': 'STREET_ADDRESS',
#    'score': 0.9545666,
#    'word': 'and 57602 søren jaabæks vei 148 apt. 961 oeschenbach, nan 27043',
#    'start': 105,
#    'end': 168}],
#  [{'entity_group': 'DATE_TIME',
#    'score': 0.96206343,
#    'word': '1',
#    'start': 40,
#    'end': 41},
#   {'entity_group': 'DATE_TIME',
#    'score': 0.961347,
#    'word': '/',
#    'start': 41,
#    'end': 42},
#   {'entity_group': 'DATE_TIME',
#    'score': 0.9610692,
#    'word': '2',
#    'start': 42,
#    'end': 43},
#   {'entity_group': 'DATE_TIME',
#    'score': 0.95844615,
#    'word': '/',
#    'start': 43,
#    'end': 44},
#   {'entity_group': 'DATE_TIME',
#    'score': 0.9528195,
#    'word': '1934',
#    'start': 44,
#    'end': 48}],
#  [{'entity_group': 'PHONE_NUMBER',
#    'score': 0.9292407,
#    'word': '03',
#    'start': 23,
#    'end': 25},
#   {'entity_group': 'PHONE_NUMBER',
#    'score': 0.8794916,
#    'word': '.',
#    'start': 25,
#    'end': 26},
#   {'entity_group': 'PHONE_NUMBER',
#    'score': 0.64400727,
#    'word': '78. 31. 72. 77',
#    'start': 26,
#    'end': 37}],
#  [{'entity_group': 'EMAIL_ADDRESS',
#    'score': 0.9337375,
#    'word': 'samiravasilyeva',
#    'start': 23,
#    'end': 38},
#   {'entity_group': 'EMAIL_ADDRESS',
#    'score': 0.61575866,
#    'word': '@',
#    'start': 38,
#    'end': 39},
#   {'entity_group': 'ORGANIZATION',
#    'score': 0.5128734,
#    'word': 'jourrapide',
#    'start': 39,
#    'end': 49},
#   {'entity_group': 'ORGANIZATION',
#    'score': 0.32780963,
#    'word': '. com',
#    'start': 49,
#    'end': 53}],
#  [{'entity_group': 'TITLE',
#    'score': 0.9268971,
#    'word': 'mrs',
#    'start': 23,
#    'end': 26},
#   {'entity_group': 'TITLE',
#    'score': 0.55838925,
#    'word': '.',
#    'start': 26,
#    'end': 27},
#   {'entity_group': 'PERSON',
#    'score': 0.9050049,
#    'word': 'forbes',
#    'start': 28,
#    'end': 34}],
#  [{'entity_group': 'DATE_TIME',
#    'score': 0.9286595,
#    'word': '2015',
#    'start': 6,
#    'end': 10},
#   {'entity_group': 'DATE_TIME',
#    'score': 0.8788902,
#    'word': '-',
#    'start': 10,
#    'end': 11},
#   {'entity_group': 'DATE_TIME',
#    'score': 0.90805286,
#    'word': '08',
#    'start': 11,
#    'end': 13},
#   {'entity_group': 'DATE_TIME',
#    'score': 0.8684032,
#    'word': '-',
#    'start': 13,
#    'end': 14},
#   {'entity_group': 'DATE_TIME',
#    'score': 0.3636341,
#    'word': '07 14 : 32 : 20',
#    'start': 14,
#    'end': 25},
#   {'entity_group': 'ORGANIZATION',
#    'score': 0.6140422,
#    'word': 'flateyri country club',
#    'start': 33,
#    'end': 54}],
#  [{'entity_group': 'DATE_TIME',
#    'score': 0.96335286,
#    'word': '4',
#    'start': 40,
#    'end': 41},
#   {'entity_group': 'DATE_TIME',
#    'score': 0.96107835,
#    'word': '/',
#    'start': 41,
#    'end': 42},
#   {'entity_group': 'DATE_TIME',
#    'score': 0.96137,
#    'word': '12',
#    'start': 42,
#    'end': 44},
#   {'entity_group': 'DATE_TIME',
#    'score': 0.95641166,
#    'word': '/',
#    'start': 44,
#    'end': 45},
#   {'entity_group': 'DATE_TIME',
#    'score': 0.94680023,
#    'word': '1947',
#    'start': 45,
#    'end': 49}],
#  [{'entity_group': 'ORGANIZATION',
#    'score': 0.6771533,
#    'word': "mervyn ' s",
#    'start': 0,
#    'end': 8},
#   {'entity_group': 'ORGANIZATION',
#    'score': 0.44272506,
#    'word': 'investment bank and financial services company',
#    'start': 28,
#    'end': 74}],
#  [{'entity_group': 'DATE_TIME',
#    'score': 0.9019889,
#    'word': '2005',
#    'start': 6,
#    'end': 10},
#   {'entity_group': 'DATE_TIME',
#    'score': 0.853823,
#    'word': '-',
#    'start': 10,
#    'end': 11},
#   {'entity_group': 'DATE_TIME',
#    'score': 0.86898845,
#    'word': '07',
#    'start': 11,
#    'end': 13},
#   {'entity_group': 'DATE_TIME',
#    'score': 0.8369932,
#    'word': '-',
#    'start': 13,
#    'end': 14},
#   {'entity_group': 'DATE_TIME',
#    'score': 0.8745001,
#    'word': '20',
#    'start': 14,
#    'end': 16},
#   {'entity_group': 'PHONE_NUMBER',
#    'score': 0.26472643,
#    'word': '23',
#    'start': 17,
#    'end': 19},
#   {'entity_group': 'DATE_TIME',
#    'score': 0.25440615,
#    'word': ':',
#    'start': 19,
#    'end': 20},
#   {'entity_group': 'PHONE_NUMBER',
#    'score': 0.2849828,
#    'word': '22',
#    'start': 20,
#    'end': 22},
#   {'entity_group': 'DATE_TIME',
#    'score': 0.22256415,
#    'word': ':',
#    'start': 22,
#    'end': 23},
#   {'entity_group': 'PHONE_NUMBER',
#    'score': 0.2785532,
#    'word': '22',
#    'start': 23,
#    'end': 25},
#   {'entity_group': 'ORGANIZATION',
#    'score': 0.5832243,
#    'word': 'woodbridge country club',
#    'start': 33,
#    'end': 56}],
#  [{'entity_group': 'EMAIL_ADDRESS',
#    'score': 0.93158984,
#    'word': 'kultsarhunor',
#    'start': 23,
#    'end': 35},
#   {'entity_group': 'EMAIL_ADDRESS',
#    'score': 0.43751732,
#    'word': '@',
#    'start': 35,
#    'end': 36},
#   {'entity_group': 'ORGANIZATION',
#    'score': 0.53698635,
#    'word': 'einrot',
#    'start': 36,
#    'end': 42},
#   {'entity_group': 'ORGANIZATION',
#    'score': 0.30280218,
#    'word': '.',
#    'start': 42,
#    'end': 43},
#   {'entity_group': 'ORGANIZATION',
#    'score': 0.33712244,
#    'word': 'com',
#    'start': 43,
#    'end': 46}],
#  [{'entity_group': 'STREET_ADDRESS',
#    'score': 0.97317326,
#    'word': '881 2 lamphey road, smarjeske toplice, slovenia',
#    'start': 127,
#    'end': 174}],
#  [{'entity_group': 'TITLE',
#    'score': 0.9211614,
#    'word': 'mrs',
#    'start': 23,
#    'end': 26},
#   {'entity_group': 'TITLE',
#    'score': 0.4981409,
#    'word': '.',
#    'start': 26,
#    'end': 27},
#   {'entity_group': 'PERSON',
#    'score': 0.85801315,
#    'word': 'tokaryev',
#    'start': 28,
#    'end': 36}],
#  [{'entity_group': 'PERSON',
#    'score': 0.45542845,
#    'word': 'wiktor',
#    'start': 30,
#    'end': 36}],
#  [{'entity_group': 'TITLE',
#    'score': 0.92847526,
#    'word': 'mrs',
#    'start': 23,
#    'end': 26},
#   {'entity_group': 'PERSON',
#    'score': 0.5186166,
#    'word': '.',
#    'start': 26,
#    'end': 27},
#   {'entity_group': 'PERSON',
#    'score': 0.93444395,
#    'word': 'jessen',
#    'start': 28,
#    'end': 34}],
#  [{'entity_group': 'PHONE_NUMBER',
#    'score': 0.8985657,
#    'word': '(',
#    'start': 23,
#    'end': 24},
#   {'entity_group': 'PHONE_NUMBER',
#    'score': 0.8647472,
#    'word': '027 ) 7705 - 596',
#    'start': 24,
#    'end': 37}],
#  [{'entity_group': 'ORGANIZATION',
#    'score': 0.4018679,
#    'word': 'jealous',
#    'start': 7,
#    'end': 14},
#   {'entity_group': 'PERSON',
#    'score': 0.8883533,
#    'word': 'jacob',
#    'start': 30,
#    'end': 35}],
#  [{'entity_group': 'PHONE_NUMBER',
#    'score': 0.93677276,
#    'word': '084 604 7849',
#    'start': 23,
#    'end': 35}],
#  [{'entity_group': 'CREDIT_CARD',
#    'score': 0.96551806,
#    'word': '4750052951907299',
#    'start': 55,
#    'end': 71},
#   {'entity_group': 'EMAIL_ADDRESS',
#    'score': 0.924456,
#    'word': 'victorcanturoque',
#    'start': 85,
#    'end': 101},
#   {'entity_group': 'EMAIL_ADDRESS',
#    'score': 0.23320806,
#    'word': '@',
#    'start': 101,
#    'end': 102},
#   {'entity_group': 'ORGANIZATION',
#    'score': 0.56821615,
#    'word': 'gustr',
#    'start': 102,
#    'end': 107},
#   {'entity_group': 'ORGANIZATION',
#    'score': 0.33465713,
#    'word': '.',
#    'start': 107,
#    'end': 108},
#   {'entity_group': 'ORGANIZATION',
#    'score': 0.28606728,
#    'word': 'com',
#    'start': 108,
#    'end': 111}],
#  [{'entity_group': 'GPE',
#    'score': 0.9323741,
#    'word': 'hungary',
#    'start': 18,
#    'end': 25}],
#  [{'entity_group': 'CREDIT_CARD',
#    'score': 0.9658919,
#    'word': '3580694588631699',
#    'start': 25,
#    'end': 41}],
#  [{'entity_group': 'CREDIT_CARD',
#    'score': 0.9632446,
#    'word': '5505682657862615',
#    'start': 25,
#    'end': 41}],
#  [{'entity_group': 'TITLE',
#    'score': 0.9454917,
#    'word': 'mrs',
#    'start': 84,
#    'end': 87},
#   {'entity_group': 'TITLE',
#    'score': 0.54192483,
#    'word': '.',
#    'start': 87,
#    'end': 88},
#   {'entity_group': 'PERSON',
#    'score': 0.9210077,
#    'word': 'renee pham',
#    'start': 89,
#    'end': 99}],
#  [{'entity_group': 'EMAIL_ADDRESS',
#    'score': 0.9298978,
#    'word': 'szolosieva',
#    'start': 23,
#    'end': 33},
#   {'entity_group': 'EMAIL_ADDRESS',
#    'score': 0.7506187,
#    'word': '@',
#    'start': 33,
#    'end': 34},
#   {'entity_group': 'ORGANIZATION',
#    'score': 0.35673413,
#    'word': 'fleckens',
#    'start': 34,
#    'end': 42},
#   {'entity_group': 'ORGANIZATION',
#    'score': 0.25104997,
#    'word': '.',
#    'start': 42,
#    'end': 43},
#   {'entity_group': 'GPE',
#    'score': 0.2515226,
#    'word': 'hu',
#    'start': 43,
#    'end': 45}],
#  [{'entity_group': 'CREDIT_CARD',
#    'score': 0.96586686,
#    'word': '5321225050427842',
#    'start': 25,
#    'end': 41}],
#  [{'entity_group': 'PERSON',
#    'score': 0.9523755,
#    'word': 'paul',
#    'start': 30,
#    'end': 34}]]

# %% [markdown]
# ## Model Interpretability Tests

# %%
# !pip install transformers-interpret

# %%
from transformers_interpret import TokenClassificationExplainer

# %%
ner_explainer = TokenClassificationExplainer(
    model,
    tokenizer,
)

# sample_text = "We visited Paris last weekend, where Emmanuel Macron lives."
sample_text = val_data.full_text.to_list()

for text in sample_text:
  word_attributions = ner_explainer(text)
  ner_explainer.visualize("bert_ner_viz.html")
